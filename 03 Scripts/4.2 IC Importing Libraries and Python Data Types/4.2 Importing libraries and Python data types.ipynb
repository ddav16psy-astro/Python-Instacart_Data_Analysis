# %% [markdown]
# # 4.2 IC Importing libraries and Python data types

# %% [markdown]
# # Table of Contents

# %% [markdown]
# #### 01. Importing libraries

# %% [markdown]
# #### 02. Python data types

# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Python data types

# %%
43 + 57
# Out:
# 100

# %%
n = 6
n + 94
# Out:
# 100

# %%
x = 212
y = 112
z = x - y
print(z)
# Out:
# 100

# %%
p = 3.14
v = 1.53
print(p/v)
# Out:
# 2.0522875816993467

# %%
m = 'Pytha'
c = 'goras'
m + c
# Out:
# 'Pythagoras'

# %%
x = 'Tableau is '
y = 'a dream!'
z = ' '
p = 'And SQL is '
t = 'a nightmare! Run away.'
x + t + z + p + y
# Out:
# 'Tableau is a nightmare! Run away. And SQL is a dream!'

# %%
# Bonus Task

# %%
q = 'ula'
q * 100
# Out:
# ''
