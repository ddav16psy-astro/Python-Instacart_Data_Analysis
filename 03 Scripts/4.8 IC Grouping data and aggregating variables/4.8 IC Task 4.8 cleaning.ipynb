# %% [markdown]
# # 4.8 TASK 4.8 Grouping data and aggregating variables

# %% [markdown]
# # Table of Contents

# %% [markdown]
# #### 01. Import libraries

# %% [markdown]
# #### 02. Delete column

# %% [markdown]
# #### 03. Delete records impacted by outliers

# %% [markdown]
# #### 04. Export dataframe as pickle file

# %% [markdown]
# # 01. Import libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Step 1

# %%
# Import dataframe

path = r'C:\Users\dirk8\CareerFoundry Projects\03-2025 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_merge_3.pkl'))

# %%
# Check the output
ords_prods_merge[53:62]
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 53   2550362        1            10                   4                  8
# 54   2550362        1            10                   4                  8
# 55   2550362        1            10                   4                  8
# 56   2550362        1            10                   4                  8
# 57   2550362        1            10                   4                  8
# 58   2550362        1            10                   4                  8
# 59   2168274        2             1                   2                 11
# 60   2168274        2             1                   2                 11
# 61   2168274        2             1                   2                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 53                    30.0       38928                  4          0
# 54                    30.0       25133                  5          1
# ...

# %%
# Check dimensions
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# # 02. Delete column

# %%
# Tutor feedback confirmed that the 'busiest_days' column is not needed, so delete it
# Dataframe before change is stored locally (as the imported ords_prods_merge_3.pkl) as backup

ords_prods_merge.drop('busiest_days', axis=1, inplace=True)

# %%
# Check the output
ords_prods_merge[53:62]
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 53   2550362        1            10                   4                  8
# 54   2550362        1            10                   4                  8
# 55   2550362        1            10                   4                  8
# 56   2550362        1            10                   4                  8
# 57   2550362        1            10                   4                  8
# 58   2550362        1            10                   4                  8
# 59   2168274        2             1                   2                 11
# 60   2168274        2             1                   2                 11
# 61   2168274        2             1                   2                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 53                    30.0       38928                  4          0
# 54                    30.0       25133                  5          1
# ...

# %%
# Check the dimensions
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %% [markdown]
# # 03. Delete records impacted by outliers

# %%
# Tutor gave me a green light to delete (or impute values) for large outliers in the 'prices' column that may be skewing mean and standard deviation
# These outliers were discovered recently rather than at the original consistency check.  Better late than never.
# To recap, showing descriptive stats on the 'prices' column

ords_prods_merge['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %% [markdown]
# __The max of 99999 and standard deviation of 496 (rounded), against a mean of 12 (rounded), confirm outlier-caused heavy skew__

# %%
# Investigating products priced above 10000

expensive_items = ords_prods_merge[ords_prods_merge['prices'] > 10000]

# %%
# Check the dimensions

expensive_items.shape
# Out:
# (5127, 18)

# %%
# Investigate a few

expensive_items.head()
# Out:
#        order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 1576     912404       17            12                   2                 14
# 1638     603376       17            22                   6                 16
# 16522   3264360      135             2                   2                 21
# 16528    892534      135             3                   0                  8
# 53672    229704      342             8                   1                 19
#
#        days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 1576                      5.0       21553                  5          0
# 1638                      4.0       21553                  3          1
# 16522                    13.0       21553                  6          0
# 16528                    12.0       21553                  3          1
# 53672                    30.0       21553                  9          0
#
# ...

# %%
# Investigate a few more

expensive_items.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32320511   3172853   205650            18                   1
# 32347717   2504315   205818             3                   5
# 32347727   1108388   205818             5                   4
# 32380527   1916142   206049             1                   2
# 32380551    379732   206049             4                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32320511                  9                     7.0       21553
# 32347717                 15                     3.0       21553
# 32347727                  5                     1.0       21553
# 32380527                 17                     NaN       21553
# 32380551                 14                     5.0       21553
#
#           add_to_cart_order  reordered                      product_name  \
# 32320511                 17          1  Lowfat 2% Milkfat Cottage Cheese
# ...

# %%
# Show stats

expensive_items.describe()
# Out:
#            order_id        user_id  order_number  orders_day_of_week  \
# count  5.127000e+03    5127.000000   5127.000000         5127.000000
# mean   1.708876e+06  106117.185684     15.302126            2.750536
# std    9.838956e+05   58594.982659     16.691849            2.010892
# min    4.300000e+01      17.000000      1.000000            0.000000
# 25%    8.642320e+05   58136.000000      4.000000            1.000000
# 50%    1.693799e+06  106021.000000      9.000000            3.000000
# 75%    2.567244e+06  156389.000000     20.000000            5.000000
# max    3.421047e+06  206049.000000     99.000000            6.000000
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count        5127.000000             4776.000000   5127.000000
# mean           13.473376               11.899079  23201.815682
# std             4.137326                9.068019   4153.742747
# min             0.000000                0.000000  21553.000000
# ...

# %%
# Show frequency counts

expensive_items['prices'].value_counts()
# Out:
# prices
# 14900.0    4429
# 99999.0     698
# Name: count, dtype: int64

# %%
# Show product_name frequency counts to investigate further

expensive_items['product_name'].value_counts()
# Out:
# product_name
# Lowfat 2% Milkfat Cottage Cheese    4429
# 2 % Reduced Fat  Milk                698
# Name: count, dtype: int64

# %% [markdown]
# __Reviewing the 2 tables above, 14900 and 99999 are clearly inaccurate prices for cottage cheese and milk, respectively.__

# %%
# Check the dimensions

expensive_items.shape
# Out:
# (5127, 18)

# %%
# Export the created expensive_items subset dataframe for backup, prior to deleting these records from the ords_prods_merge dataframe

expensive_items.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'expensive_items.pkl'))

# %% [markdown]
# # Correct the 'prices' column data significant inaccuracies via deletion of impacted records

# %%
# Check dimensions of ords_prods_merge
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
# Delete rows where 'prices' column value equals 14900 or 99999 from the dataframe, to correct significant price inaccuracies that skew analysis

ords_prods_merge_1 = ords_prods_merge[ords_prods_merge['prices'].isin([14900, 99999]) == False]

# %%
# Check the dimensions

ords_prods_merge_1.shape
# Out:
# (32399732, 18)

# %%
# Check the output

ords_prods_merge_1.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# Check whether 'prices' condition caused relevant records to be deleted

ords_prods_merge_1[ords_prods_merge_1['prices'] > 10000]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, price_range_loc, busiest_day, busiest_period_of_day, max_order, loyalty_flag]
# Index: []

# %%
# Check stats of original dataframe

ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.032876e+07  3.240486e+07
# mean        1.342515e+01            1.110408e+01  2.559866e+04
# std         4.246380e+00            8.779064e+00  1.408400e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
# Check the dimensions

ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
# Export ords_prods_merge dataframe as backup before deletions were made

ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_merge_4.pkl'))

# %%
# Import libraries and dataframe

import pandas as pd
import numpy as np
import os

path = r'C:\Users\dirk8\CareerFoundry Projects\03-2025 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_merge_4.pkl'))

# %%
# Check the dimensions

ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
# Check the output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# Delete rows where 'prices' column value < 14900

ords_prods_merge = ords_prods_merge[ords_prods_merge['prices'] < 14900]

# %%
# Check the dimensions

ords_prods_merge.shape
# Out:
# (32399732, 18)

# %%
# Check the stats

ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.239973e+07  3.239973e+07  3.239973e+07        3.239973e+07
# mean   1.710746e+06  1.029367e+05  1.714260e+01        2.738865e+00
# std    9.872994e+05  5.946623e+04  1.753544e+01        2.090089e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559450e+05  5.142000e+04  5.000000e+00        1.000000e+00
# 50%    1.711052e+06  1.026140e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543880e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.239973e+07            3.032399e+07  3.239973e+07
# mean        1.342514e+01            1.110395e+01  2.559904e+04
# std         4.246397e+00            8.779012e+00  1.408498e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# __The 'prices' column stats now look good, with a maximum of 25, minimum of 1, mean of 7.79 and standard deviation of 4.24__

# %%
# Check the output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# # 04. Export dataframe as pickle file

# %%
# Export the dataframe

ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_merge_5.pkl'))
